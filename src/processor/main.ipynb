# %%
import pandas as pd
from pathlib import Path

# %%
root = Path("../../data")
file = root / "main.csv"

# %%
Path().absolute()
# Out:
# PosixPath('/Users/anton/Projects/vogelring/src/processor')

# %%
df = pd.read_csv(file, sep=";")
df = df.drop(
    [
        "Koordinaten",
        "IngLong",
        "IngLat",
        "Spalte1",
        "Tag",
        "Monat",
        "Jahr",
        "strSpecies",
        "strRingScheme",
        "Nummer",
        "Bein",
        "Ort3",
        "Unnamed: 26",
        "Datum2",
        "dtmDate",
        "strSex",
        "strAge",
        "Alter",
    ],
    axis=1,
)
df.head()
# Out:
#           Art RingString Ablesung    Datum               Ort  \
# 0     Nilgans        HE2      HE2  5/19/11       Alte Brücke
# 1  Kanadagans     290379  290 379  2/24/19           Ostpark
# 2    Graugans     274848   274848  4/17/19           Ostpark
# 3    Graugans     290334  290 334  6/29/20  Höchst Stadtpark
# 4    Graugans     290335  290 335  7/19/19  Höchst Stadtpark
#
#                                         Gruppengröße  Bemerkung       Melder  \
# 0                                                 45        NaN          NaN
# 1  31 (278962/…/970/…279000/ 290379/; außerdem: (...        NaN           IR
# 2                                               solo        NaN           IR
# 3                                     Gesamt 53 (21)  flugfähig           IR
# 4                                                NaN        NaN  Usinger, H.
#
#   gemeldet
# 0      577
# 1
# 2        ?
# 3        ?
# 4        ?

# %%
def to_int_or_nan(x):
    try:
        return int(x)
    except (ValueError, TypeError):
        return pd.NA


df["Gruppengröße"] = df["Gruppengröße"].apply(to_int_or_nan)

# Show the results
df.head()
# Out:
#           Art RingString Ablesung    Datum               Ort Gruppengröße  \
# 0     Nilgans        HE2      HE2  5/19/11       Alte Brücke           45
# 1  Kanadagans     290379  290 379  2/24/19           Ostpark         <NA>
# 2    Graugans     274848   274848  4/17/19           Ostpark         <NA>
# 3    Graugans     290334  290 334  6/29/20  Höchst Stadtpark         <NA>
# 4    Graugans     290335  290 335  7/19/19  Höchst Stadtpark         <NA>
#
#    Bemerkung       Melder gemeldet
# 0        NaN          NaN      577
# 1        NaN           IR
# 2        NaN           IR        ?
# 3  flugfähig           IR        ?
# 4        NaN  Usinger, H.        ?

# %%
# Remove quotes from both columns
df["Bemerkung"] = df["Bemerkung"].str.replace('"', "").str.replace("'", "")
df["Melder"] = df["Melder"].str.replace('"', "").str.replace("'", "")
df["Ort"] = df["Ort"].str.replace('"', "").str.replace("'", "")

# %%
# Drop rows where any of these columns are empty
print(f"Shape before dropping empty rows: {df.shape}")
df = df.dropna(subset=["Art", "RingString", "Ablesung"])

# Show the results and the new shape
print(f"Shape after dropping empty rows: {df.shape}")
# Out:
# Shape before dropping empty rows: (6639, 9)
# Shape after dropping empty rows: (6639, 9)

# %%
df.to_csv(root / "out" / "main.csv")
